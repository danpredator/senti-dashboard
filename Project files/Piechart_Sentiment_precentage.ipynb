# %%
import pandas as pd

# %%
df2 = pd.read_csv('D:\\Nikhil\\dcumnts\\Certificates\\others\\IBMhc\\ds\\date_sentiment.csv',  encoding='ISO-8859-1')

# %%
df2.shape
# Out:
# (7712, 4)

# %%
pos=0
neu=0
neg=0

# %%
for i in range(0,7712):
    val=df2['sentiment_value_r'][i]
    if val==0:
        neu=neu+1
    elif val==1:
        pos=pos+1
    else:
        neg=neg+1

# %%
print(pos,neu,neg)
# Out:
# 3969 2472 1271

# %%
pos+neu+neg+vpos+vneg
# Out:
# 7712

# %% [markdown]
# Persentage of past sentiments

# %%
(neg/7712)*100
# Out:
# 16.480809128630707

# %%
(pos/7712)*100
# Out:
# 51.46524896265559

# %%
(neu/7712)*100
# Out:
# 32.053941908713696
